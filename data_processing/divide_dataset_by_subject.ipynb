# %%
import pandas as pd
import seaborn as sb
import matplotlib as plot

# %%
data = pd.read_csv(r'../dataset/full.csv')

subject = data.sort_values(by='subject', ascending=False)

for i in range(30):
    j = i + 1
    divided_set = pd.DataFrame()
    try:
        divided_set = data[data['subject'] == i + 1]
    except (IndexError):
        pass
    if not divided_set.empty:
        divided_set.to_csv(rf'../dataset/data_subject{j}.csv', index=False)
# Out:
# [ 1  3  5  6  7  8 11 14 15 16 17 19 21 22 23 25 26 27 28 29 30  2  4  9
#  10 12 13 18 20 24]
